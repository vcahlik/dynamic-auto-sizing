# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import itertools
import random
plt.style.use('seaborn-paper')

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
# set matplotlib font to Times
from matplotlib import rc
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)

# %% [markdown]
# ## L1 vs. L2 regularization

# %%
f = plt.figure()

x = np.linspace(-1.5, 1.5, num=200)
# plt.plot(x, (x**2), 'k', label=r"$\alpha=0$")
# plt.plot(x, (x**2) * ((np.sign(x) + 0.2) ** 2), 'k:', label=r"$\alpha=0.2$")
plt.plot(x, x ** 2, 'k--', label=r'$l_2$')
plt.plot(x, abs(x), 'k', label=r'$l_1$')
plt.xlabel(r'$\theta{}_i$', fontsize=13)
plt.ylabel(r'$\Omega(\theta{}_i)$', fontsize=13)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.legend(fontsize=11, loc='lower right')

plt.xlim(-1.5, 1.5)
plt.ylim(0, 2)

f.savefig("l1-12-regularization.pdf", bbox_inches='tight')

# %% [markdown]
# ## Grid search

# %%
import itertools

f = plt.figure()

x = np.linspace(1, 3, num=3)
y = np.linspace(1, 3, num=3)
product = list(itertools.product(x, y))
x = [x[0] for x in product]
y = [x[1] for x in product]

plt.scatter(x, y, c='black')
plt.vlines(x, 0, y, linestyle="dotted", colors='grey')
plt.hlines(y, 0, x, linestyle="dotted", colors='grey')
# plt.plot(x, abs(x), 'k', label=r'$l_1$')
plt.xlabel(r'$a$', fontsize=13)
plt.ylabel(r'$b$', fontsize=13)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
# plt.title('Grid search', fontsize=16)
# plt.legend(fontsize=11, loc='lower right')

plt.xlim(0.5, 3.5)
plt.ylim(0.5, 3.5)

f.savefig("grid-search.pdf", bbox_inches='tight')

# %% [markdown]
# ## Random search

# %%
f = plt.figure()

x = np.random.uniform(0.5, 3.5, 9)
y = np.random.uniform(0.5, 3.5, 9)

plt.scatter(x, y, c='black')
plt.vlines(x, 0, y, linestyle="dotted", colors='grey')
plt.hlines(y, 0, x, linestyle="dotted", colors='grey')
# plt.plot(x, abs(x), 'k', label=r'$l_1$')
plt.xlabel(r'$a$', fontsize=13)
plt.ylabel(r'$b$', fontsize=13)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
# plt.title('Random search', fontsize=16)
# plt.legend(fontsize=11, loc='lower right')

plt.xlim(0.5, 3.5)
plt.ylim(0.5, 3.5)

f.savefig("random-search.pdf", bbox_inches='tight')

# %% [markdown]
# ## Sigmoid function

# %%
f = plt.figure(figsize=(8, 4))

min_value = -6
max_value = 6

x = np.linspace(min_value, max_value, num=200)
# plt.plot(x, (x**2), 'k', label=r"$\alpha=0$")
# plt.plot(x, (x**2) * ((np.sign(x) + 0.2) ** 2), 'k:', label=r"$\alpha=0.2$")
plt.plot(x, 1/(1 + np.exp(-x)), 'k', label=r'$y=\sigma(x)$')
plt.plot(x, 1/(1 + np.exp(-x)) * (1 - 1/(1 + np.exp(-x))), 'k--', label=r"$y=\sigma{}'(x)$")
plt.xlabel(r'$x$', fontsize=13)
plt.ylabel(r'$y$', fontsize=13)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.legend(fontsize=11, loc='upper left')

plt.xlim(min_value, max_value)
plt.ylim(0, 1)

f.savefig("sigmoid.pdf", bbox_inches='tight')

# %% [markdown]
# ## ReLU function

# %%
f = plt.figure(figsize=(4,3))

min_value = -5
max_value = 5

x = np.linspace(min_value, max_value, num=200)
# plt.plot(x, (x**2), 'k', label=r"$\alpha=0$")
# plt.plot(x, (x**2) * ((np.sign(x) + 0.2) ** 2), 'k:', label=r"$\alpha=0.2$")
plt.plot(x, 0*x, linestyle="dotted", color='grey')
plt.plot(x, np.maximum(np.zeros(shape=x.shape),x), 'k')
plt.xlabel(r'$x$', fontsize=13)
plt.ylabel(r'$ReLU(x)$', fontsize=13)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
# plt.legend(fontsize=11, loc='upper left')

plt.xlim(min_value, max_value)
plt.ylim(-2, 5)

f.savefig("relu.pdf", bbox_inches='tight')

# %% [markdown]
# ## Leaky ReLU function

# %%
f = plt.figure(figsize=(4,3))

min_value = -5
max_value = 5

x = np.linspace(min_value, max_value, num=200)
# plt.plot(x, (x**2), 'k', label=r"$\alpha=0$")
# plt.plot(x, (x**2) * ((np.sign(x) + 0.2) ** 2), 'k:', label=r"$\alpha=0.2$")
plt.plot(x, 0*x, linestyle="dotted", color='grey')
plt.plot(x, np.maximum(np.zeros(shape=x.shape),x) + 0.2 * np.minimum(np.zeros(shape=x.shape),x), 'k')
plt.xlabel(r'$x$', fontsize=13)
plt.ylabel(r'$LeakyReLU(x)$', fontsize=13)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
# plt.legend(fontsize=11, loc='upper left')

plt.xlim(min_value, max_value)
plt.ylim(-2, 5)

f.savefig("leaky-relu.pdf", bbox_inches='tight')

# %% [markdown]
# ## ELU function

# %%
f = plt.figure(figsize=(4,3))

min_value = -5
max_value = 5

x = np.linspace(min_value, max_value, num=200)
plt.plot(x, 0*x, linestyle="dotted", color='grey')
plt.plot(x, np.where(x > 0, x, (np.exp(x) - 1)), 'k')
plt.xlabel(r'$x$', fontsize=13)
plt.ylabel(r'$ELU(x)$', fontsize=13)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
# plt.legend(fontsize=11, loc='upper left')

plt.xlim(min_value, max_value)
plt.ylim(-2, 5)

f.savefig("elu.pdf", bbox_inches='tight')

# %% [markdown]
# ## SELU function

# %%
f = plt.figure(figsize=(4,3))

min_value = -5
max_value = 5

x = np.linspace(min_value, max_value, num=200)
plt.plot(x, 0*x, linestyle="dotted", color='grey')
plt.plot(x, 1.0507009 * np.where(x > 0, x, 1.673263 * (np.exp(x) - 1)), 'k')
plt.xlabel(r'$x$', fontsize=13)
plt.ylabel(r'$SELU(x)$', fontsize=13)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
# plt.legend(fontsize=11, loc='upper left')

plt.xlim(min_value, max_value)
plt.ylim(-2, 5)

f.savefig("selu.pdf", bbox_inches='tight')

# %% [markdown]
# ## Anytime grid search

# %%
def _raw_relative_combinations_for_level(level, n_range_arguments):
    l = level + 1
    single_argument_values = tuple(i / (2 ** l) for i in range(1, 2 ** l))
    all_argument_values = [single_argument_values for _ in range(n_range_arguments)]
    return list(itertools.product(*all_argument_values))

def get_relative_combinations_for_level(level, n_range_arguments):
    relative_combinations = set(_raw_relative_combinations_for_level(level, n_range_arguments))
    previous_combinations = set()
    for i in range(0, level):
        previous_combinations = previous_combinations.union(set(_raw_relative_combinations_for_level(i, n_range_arguments)))
    relative_combinations = list(relative_combinations.difference(previous_combinations))
    random.shuffle(relative_combinations)
    return relative_combinations

# %%
f = plt.figure()

points = get_relative_combinations_for_level(0, 2)
x = [x[0] for x in points]
y = [x[1] for x in points]
plt.scatter(x, y, c='black', marker='s', label="Level 1")

points = get_relative_combinations_for_level(1, 2)
x = [x[0] for x in points]
y = [x[1] for x in points]
plt.scatter(x, y, color=(0.25, 0.25, 0.25), marker='x', label="Level 2")

points = get_relative_combinations_for_level(2, 2)
x = [x[0] for x in points]
y = [x[1] for x in points]
plt.scatter(x, y, c='grey', marker='2', label="Level 3")

points = get_relative_combinations_for_level(3, 2)
x = [x[0] for x in points]
y = [x[1] for x in points]
plt.scatter(x, y, color=(0.85, 0.85, 0.85), marker='.', label="Level 4")

plt.xlabel(r'$a$', fontsize=13)
plt.ylabel(r'$b$', fontsize=13)
legend = plt.legend(fontsize=11)
frame = legend.get_frame()
frame.set_alpha(1)

plt.xlim(0, 1)
plt.ylim(0, 1)

f.savefig("anytime-grid-search.pdf", bbox_inches='tight')

# %% [markdown]
# ## Final layer sizes, identical configuration

# %%
final_hidden_layer_sizes = [
    [69, 23, 29, 72, 218],
    [59, 23, 26, 73, 224],
    [63, 22, 27, 62, 219],
    [60, 24, 27, 68, 211],
    [67, 24, 27, 69, 219],
    [61, 23, 26, 72, 219],
    [59, 26, 32, 59, 224],
    [58, 25, 29, 66, 222],
    [71, 23, 28, 58, 224],
    [65, 20, 34, 51, 221]
]
final_hidden_layer_sizes_transposed = np.array(final_hidden_layer_sizes).T.tolist()

# %%
f = plt.figure()

plt.plot(['Conv 1', 'Conv 2', 'Conv 3', 'Conv 4', 'Dense'], final_hidden_layer_sizes_transposed, marker='.', alpha=0.3, color='black')
plt.xlabel("Layer", fontsize=13)
plt.ylabel("Final Number of units", fontsize=13)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)

f.savefig("stability.pdf", bbox_inches='tight')

# %%
colors = [
    'tab:blue',
    'tab:orange',
    'tab:green',
    'tab:red',
    'tab:purple',
    'tab:brown',
    'tab:pink',
    'tab:gray',
    'tab:olive',
    'tab:cyan',
]

# %%
f = plt.figure()

plt.plot(['Conv 1', 'Conv 2', 'Conv 3', 'Conv 4', 'Dense'], final_hidden_layer_sizes_transposed, marker='.', alpha=0.7)
plt.xlabel("Layer", fontsize=15)
plt.ylabel("Final Number of units", fontsize=15)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

f.savefig("stability.pdf", bbox_inches='tight')

# %% [markdown]
# ## Final layer sizes, various initial numbers of units

# %%
final_hidden_layer_sizes = [
    [25, 25, 25, 73, 228],
    [48, 31, 31, 75, 210],
    [63, 26, 28, 70, 212],
    [64, 23, 29, 71, 221],
    [68, 23, 29, 68, 212],
    [58, 22, 26, 68, 218]
]
hidden_layer_size_schedule = [25, 50, 75, 100, 125, 150]

# %%
f = plt.figure()
ax = f.add_subplot(1, 1, 1)

for i, (initial_hidden_layer_size, metric) in enumerate(zip(hidden_layer_size_schedule, final_hidden_layer_sizes)):
    label = f"{initial_hidden_layer_size} initial units"
    plt.plot(['Conv 1', 'Conv 2', 'Conv 3', 'Conv 4', 'Dense'], metric, label=label, marker='.', alpha=(i+1)/6, color='black')
plt.xlabel("Layer", fontsize=13)
plt.ylabel("Final number of units", fontsize=13)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
handles, labels = ax.get_legend_handles_labels()
plt.legend(reversed(handles), reversed(labels), fontsize=11)

f.savefig("stability-different-initial-sizes.pdf", bbox_inches='tight')

# %%
f = plt.figure()
ax = f.add_subplot(1, 1, 1)

for i, (initial_hidden_layer_size, metric) in enumerate(zip(hidden_layer_size_schedule, final_hidden_layer_sizes)):
    label = f"{initial_hidden_layer_size} initial units"
    plt.plot(['Conv 1', 'Conv 2', 'Conv 3', 'Conv 4', 'Dense'], metric, label=label, marker='.', alpha=0.7, color=colors[i])
plt.xlabel("Layer", fontsize=15)
plt.ylabel("Final number of units", fontsize=15)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
handles, labels = ax.get_legend_handles_labels()
plt.legend(reversed(handles), reversed(labels), fontsize=13)

f.savefig("stability-different-initial-sizes.pdf", bbox_inches='tight')

# %% [markdown]
# ## Final layer sizes, shared figure

# %%
from matplotlib import gridspec

ylim = (15, 235)

# Simple data to display in various forms
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

fig = plt.figure(figsize=(10, 3))
# set height ratios for subplots
gs = gridspec.GridSpec(1, 2) 

# the first subplot
ax0 = plt.subplot(gs[0])


line0 = ax0.plot(['Conv 1', 'Conv 2', 'Conv 3', 'Conv 4', 'Dense'], final_hidden_layer_sizes_transposed, marker='.', lw=2, alpha=0.6)
ax0.set_xlabel("Layer", fontsize=15)
ax0.set_ylabel("Final Number of units", fontsize=15)
ax0.set_ylim(*ylim)
ax0.tick_params(labelsize=13)
ax0.grid(axis='y', linewidth=0.3)


# line0, = ax0.plot(x, y, color='r')


# the second subplot
# shared axis X
ax1 = plt.subplot(gs[1], sharex = ax0)


for i, (initial_hidden_layer_size, metric) in enumerate(zip(hidden_layer_size_schedule, final_hidden_layer_sizes)):
    label = f"{initial_hidden_layer_size} initial units"
    ax1.plot(['Conv 1', 'Conv 2', 'Conv 3', 'Conv 4', 'Dense'], metric, label=label, marker='.', lw=2, alpha=0.6, color=colors[i])
ax1.set_xlabel("Layer", fontsize=15)
# ax1.set_ylabel("Final number of units", fontsize=15)
ax1.set_ylim(*ylim)
ax1.tick_params(labelsize=13)
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(reversed(handles), reversed(labels), fontsize=13)
ax1.grid(axis='y', linewidth=0.3)


# line1, = ax1.plot(x, y, color='b', linestyle='--')


plt.setp(ax1.get_yticklabels(), visible=False)
# remove last tick label for the second subplot
ax1.tick_params(left=False)  # remove the ticks
yticks = ax1.yaxis.get_major_ticks()
yticks[-1].label1.set_visible(False)

# put legend on first subplot
# ax0.legend((line0, line1), ('red line', 'blue line'), loc='lower left')

# remove vertical gap between subplots
plt.subplots_adjust(wspace=.1)
plt.show()

fig.savefig("stability-joint.pdf", bbox_inches='tight')

# %% [markdown]
# ## Evolution of number of filters

# %%
evolutions = [
    [[25, 25, 25, 25, 45],
    [25, 25, 25, 27, 65],
    [25, 25, 25, 28, 85],
    [25, 25, 25, 34, 105],
    [25, 25, 25, 36, 126],
    [25, 25, 25, 42, 150],
    [25, 25, 25, 46, 173],
    [25, 25, 25, 53, 191],
    [25, 25, 25, 57, 210],
    [25, 25, 25, 56, 216],
    [25, 25, 26, 60, 217],
    [25, 25, 25, 62, 223],
    [25, 25, 25, 65, 225],
    [25, 25, 25, 70, 224],
    [25, 25, 25, 71, 227],
    [25, 25, 25, 70, 224],
    [25, 25, 25, 75, 224],
    [25, 25, 25, 74, 225],
    [25, 25, 26, 73, 228],
    [25, 25, 25, 73, 228]],
    [[50, 50, 50, 50, 70],
    [50, 50, 50, 51, 90],
    [50, 50, 50, 53, 108],
    [50, 50, 50, 50, 126],
    [50, 50, 50, 51, 146],
    [50, 48, 50, 53, 156],
    [50, 47, 49, 56, 169],
    [50, 45, 49, 59, 185],
    [50, 43, 48, 63, 190],
    [50, 40, 46, 65, 198],
    [50, 39, 45, 62, 200],
    [50, 39, 44, 66, 202],
    [50, 39, 37, 72, 202],
    [50, 35, 36, 72, 205],
    [50, 33, 35, 71, 204],
    [50, 33, 32, 72, 207],
    [49, 33, 34, 75, 207],
    [49, 33, 31, 75, 209],
    [48, 32, 31, 72, 209],
    [48, 31, 31, 75, 210]],
    [[75, 75, 75, 75, 95],
    [75, 75, 75, 75, 106],
    [75, 75, 74, 75, 118],
    [75, 68, 69, 75, 141],
    [75, 61, 61, 71, 163],
    [75, 56, 60, 69, 184],
    [74, 39, 56, 69, 194],
    [74, 35, 51, 69, 199],
    [74, 35, 43, 69, 201],
    [73, 34, 41, 69, 205],
    [73, 33, 41, 67, 206],
    [71, 32, 39, 71, 206],
    [70, 31, 37, 69, 207],
    [69, 31, 34, 69, 206],
    [68, 31, 34, 70, 207],
    [68, 28, 32, 71, 208],
    [66, 28, 31, 70, 209],
    [63, 28, 30, 70, 211],
    [63, 27, 29, 70, 210],
    [63, 26, 28, 70, 212]],
    [[100, 100, 100, 100, 120],
    [100, 100, 100, 100, 134],
    [100, 70, 80, 83, 150],
    [100, 55, 68, 73, 170],
    [100, 47, 61, 66, 185],
    [100, 37, 54, 61, 188],
    [99, 35, 49, 64, 203],
    [97, 33, 48, 66, 207],
    [93, 27, 46, 65, 216],
    [92, 25, 43, 66, 216],
    [85, 25, 40, 64, 220],
    [79, 26, 37, 68, 217],
    [75, 25, 35, 64, 220],
    [72, 24, 35, 62, 218],
    [68, 24, 34, 64, 219],
    [67, 23, 33, 67, 219],
    [65, 23, 33, 66, 221],
    [65, 23, 32, 69, 220],
    [64, 23, 31, 72, 222],
    [64, 23, 29, 71, 221]],
    [[125, 125, 125, 125, 125],
    [125, 118, 123, 121, 129],
    [125, 62, 80, 84, 146],
    [125, 49, 62, 72, 161],
    [124, 39, 58, 65, 173],
    [120, 35, 48, 61, 188],
    [117, 32, 46, 60, 200],
    [109, 28, 43, 58, 206],
    [100, 26, 42, 58, 211],
    [95, 24, 41, 63, 213],
    [91, 24, 37, 62, 212],
    [90, 24, 36, 62, 212],
    [85, 24, 33, 67, 211],
    [80, 24, 32, 66, 213],
    [77, 24, 32, 65, 215],
    [76, 24, 30, 68, 215],
    [73, 24, 29, 70, 213],
    [73, 23, 29, 70, 214],
    [71, 23, 29, 68, 213],
    [68, 23, 29, 68, 212]],
    [[150, 150, 150, 150, 150],
    [150, 114, 113, 115, 164],
    [150, 56, 71, 74, 175],
    [149, 40, 66, 65, 185],
    [143, 36, 57, 62, 192],
    [127, 31, 52, 62, 202],
    [119, 29, 49, 62, 207],
    [109, 27, 41, 56, 211],
    [103, 25, 40, 59, 209],
    [97, 24, 37, 65, 215],
    [88, 24, 32, 65, 219],
    [80, 22, 32, 62, 221],
    [76, 22, 32, 57, 218],
    [73, 22, 30, 66, 217],
    [69, 22, 30, 66, 217],
    [65, 22, 29, 63, 217],
    [62, 22, 29, 69, 219],
    [60, 22, 29, 69, 217],
    [59, 22, 26, 66, 219],
    [58, 22, 26, 68, 218]]
]
hidden_layer_size_schedule = [25, 50, 75, 100, 125, 150]

# %%
f = plt.figure()
ax = f.add_subplot(1, 1, 1)

for i, (initial_hidden_layer_size, evolution) in enumerate(zip(hidden_layer_size_schedule, evolutions)):
    epochs_list = list(range(1, len(evolution) + 1))
    label = f"Initial units: {initial_hidden_layer_size}"
    evolution_single_layer = [i[3] for i in evolution]
    plt.plot(epochs_list, evolution_single_layer, label=label, alpha=(i+1)/6, color='black')
plt.xlabel("Epoch", fontsize=13)
plt.ylabel("Number of units", fontsize=13)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
handles, labels = ax.get_legend_handles_labels()
plt.legend(reversed(handles), reversed(labels), fontsize=11)

f.savefig("model-size-evolution-different-initial-sizes.pdf", bbox_inches='tight')

# %%
f = plt.figure()
ax = f.add_subplot(1, 1, 1)

for i, (initial_hidden_layer_size, evolution) in enumerate(zip(hidden_layer_size_schedule, evolutions)):
    epochs_list = list(range(1, len(evolution) + 1))
    label = f"{initial_hidden_layer_size} initial units"
    evolution_single_layer = [i[3] for i in evolution]
    plt.plot(epochs_list, evolution_single_layer, label=label, alpha=0.8, color=colors[i])
plt.xlabel("Epoch", fontsize=13)
plt.ylabel("Number of units", fontsize=13)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
handles, labels = ax.get_legend_handles_labels()
plt.legend(reversed(handles), reversed(labels), fontsize=11)

f.savefig("model-size-evolution-different-initial-sizes.pdf", bbox_inches='tight')

# %% [markdown]
# ## Final layer sizes with varying regularization strength

# %%
all_layer_sizes = [
    [[7, 5, 4, 5, 11],
    [8, 4, 10, 2, 21],
    [6, 8, 4, 3, 12],
    [6, 7, 4, 5, 11],
    [7, 7, 3, 4, 13]],

    [[17, 18, 17, 13, 31],
    [19, 17, 17, 13, 26],
    [21, 16, 15, 11, 33],
    [20, 18, 10, 13, 30],
    [18, 16, 14, 10, 32]],

    [[52, 62, 34, 40, 44],
    [56, 47, 37, 37, 50],
    [51, 67, 39, 40, 49],
    [54, 47, 39, 44, 42],
    [56, 51, 38, 41, 46]],

    [[78, 70, 70, 68, 55],
    [76, 70, 70, 69, 49],
    [78, 70, 70, 70, 48],
    [74, 70, 70, 69, 62],
    [81, 70, 61, 63, 62]],
]

# %%
f = plt.figure()

for i, (initial_hidden_layer_size, evolution) in enumerate(zip(hidden_layer_size_schedule, evolutions)):
    epochs_list = list(range(1, len(evolution) + 1))
    label = f"Initial units: {initial_hidden_layer_size}"
    evolution_single_layer = [i[3] for i in evolution]
    plt.plot(epochs_list, evolution_single_layer, label=label, alpha=(i+1)/6, color='black')
plt.xlabel("Epoch", fontsize=13)
plt.ylabel("Number of units", fontsize=13)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.legend(fontsize=11)

f.savefig("model-size-evolution-different-initial-sizes.pdf", bbox_inches='tight')

# %%
f = plt.figure()

for alpha, regularization_penalty, layer_sizes_of_same_penalty in zip([0.15, 0.3, 0.55, 1], reversed([0.02, 0.002, 0.0002, 0.00002]), reversed(all_layer_sizes)):
    for i, layer_sizes in enumerate(layer_sizes_of_same_penalty):
        if i == 0:
            label = f"$\\alpha$={np.format_float_positional(regularization_penalty, trim='-')}"
        else:
            label = None
        plt.plot(['Dense 1', 'Dense 2', 'Dense 3', 'Dense 4', 'Dense 5'], layer_sizes, label=label, c='black', marker='.', alpha=alpha)
plt.xlabel("Layer", fontsize=13)
plt.ylabel("Final number of units", fontsize=13)
legend = plt.legend(loc='upper right', fontsize=11)
plt.savefig('model-size-different-regularization.png')
# plt.yscale('log')
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)

f.savefig("model-size-different-regularization.pdf", bbox_inches='tight')

# %%
f = plt.figure()

for j, regularization_penalty, layer_sizes_of_same_penalty in zip([0, 1, 2, 3], reversed([0.02, 0.002, 0.0002, 0.00002]), reversed(all_layer_sizes)):
    for i, layer_sizes in enumerate(layer_sizes_of_same_penalty):
        if i == 0:
            label = f"$\\alpha$={np.format_float_positional(regularization_penalty, trim='-')}"
        else:
            label = None
        plt.plot(['Dense 1', 'Dense 2', 'Dense 3', 'Dense 4', 'Dense 5'], layer_sizes, label=label, c=colors[j], marker='.', alpha=0.6)
plt.xlabel("Layer", fontsize=13)
plt.ylabel("Final number of units", fontsize=13)
legend = plt.legend(loc='upper right', fontsize=11)
plt.savefig('model-size-different-regularization.png')
# plt.yscale('log')
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)

f.savefig("model-size-different-regularization.pdf", bbox_inches='tight')

# %% [markdown]
# # Figures for reference

# %% [markdown]
# ## Activation functions

# %%
f = plt.figure()

x_start = -3
x_end = 3

x = np.linspace(x_start, x_end)
relu = np.linspace(x_start, x_end)
elu = np.linspace(x_start, x_end)

relu[relu<0] = 0
relu[relu>0] = x[x>0]

elu[elu<0] = np.exp(x[x<0]) - 1
elu[elu>0] = x[x>0]

plt.plot(x, 1 / (1 + np.exp(-x)), 'k', label=r"Sigmoid")
plt.plot(x, relu, 'k:', label=r"ReLU")
plt.plot(x, elu, 'k-.', label=r"ELU")
plt.xlabel('$x$', fontsize=13)
plt.ylabel('$f(x)$', fontsize=13)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.legend(fontsize=11);

plt.grid(True)
plt.xlim(-3, 3)
plt.ylim(-1, 2)

f.savefig("activation-functions.pdf", bbox_inches='tight')

# %% [markdown]
# ## Training dataset

# %%
f = plt.figure()

costs = pd.read_csv("~/code/fifteen-puzzle/data/datasets/15-costs-v3.csv", nrows=1000000).cost
weights = np.ones_like(costs) / float(len(costs))
plt.hist(costs, bins=15, weights=weights, color='k')
plt.xlabel('Optimal solution cost', fontsize=13)
plt.ylabel('Relative frequency', fontsize=13)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)

f.savefig("training-dataset-histogram.pdf", bbox_inches='tight')
